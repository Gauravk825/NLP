# %%
# !pip install morfessor
# Out:
# ...
#   Using cached Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# ...

# %%
# !pip install pyICU
# Out:
# ...
#   Using cached PyICU-2.13.1.tar.gz (262 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [66 lines of output]
#       (running 'icu-config --version')
#       (running 'pkg-config --modversion icu-i18n')
#       Traceback (most recent call last):
#         File "<string>", line 89, in <module>
#         File "<frozen os>", line 679, in __getitem__
#       KeyError: 'ICU_VERSION'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 92, in <module>
#         File "<string>", line 19, in check_output
# ...

# %%
pip install polyglot
# Out:
# ...
#   Using cached polyglot-16.7.4.tar.gz (126 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for polyglot: filename=polyglot-16.7.4-py2.py3-none-any.whl size=52602 sha256=511b67a32590779efa311fabc2bcf874e022e815dd758f6288d46c85d6b02661
#   Stored in directory: c:\users\gaurav\appdata\local\pip\cache\wheels\70\e3\da\d2f524831513cedfe2a49e46a94028bf6f632f6ba172d6dead
# Successfully built polyglot
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pycld2

# %%
# %%bash
# polyglot download morph2.en morph2.mr
# Out:
# [polyglot_data] Downloading package morph2.en to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data] Downloading package morph2.mr to
# [polyglot_data]     /root/polyglot_data...

# %%
from polyglot.text import Text, Word

# %%
words = ['cats', 'computing', 'association', 'programming',
         'leadership', 'miscommunication', 'identifiable', 'psychologically',
         'engineering', 'tabular', 'realistic', 'colofulness']

# %%
for w in words:
  w = Word(w, language='en')
  print(w, '\t\t', w.morphemes)
# Out:
# cats 		 ['cat', 's']
# computing 		 ['com', 'put', 'ing']
# association 		 ['associ', 'ation']
# programming 		 ['program', 'ming']
# leadership 		 ['leader', 'ship']
# miscommunication 		 ['mis', 'communication']
# identifiable 		 ['identif', 'i', 'able']
# psychologically 		 ['psycho', 'logical', 'ly']
# engineering 		 ['engine', 'er', 'ing']
# tabular 		 ['tab', 'ular']
# realistic 		 ['real', 'istic']
# colofulness 		 ['co', 'lo', 'ful', 'ness']

# %%
words = ['श्रीनिवास', 'जलविघुत']
for w in words:
  w = Word(w, language='mr')
  print(w, '\t\t', w.morphemes)
# Out:
# श्रीनिवास 		 ['श्री', 'निवास']
# जलविघुत 		 ['जल', 'वि', 'घु', 'त']

# %%
blob = 'Wewillmeettoday.'
text = Text(blob)
text.language = 'en'

# %%
text.morphemes
# Out:
# WordList(['We', 'will', 'meet', 'to', 'day', '.'])

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger') # Download the tagger resources if you haven't already
from nltk import pos_tag
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
text = "Venus is the second planet from the Sun. It is a terrestrial planet and is the closest in mass and size to its orbital neighbour Earth. Venus is notable for having the densest atmosphere of the terrestrial planets, composed mostly of carbon dioxide with a thick, global sulfuric acid cloud cover. At the surface it has a mean temperature of 737 K (464 °C; 867 °F) and a pressure of 92 times that of Earth's at sea level. These extreme conditions compress carbon dioxide into a supercritical state close to Venus's surface."

# %%
tags = pos_tag(word_tokenize(text))

# %%
tags
# Out:
# [('Venus', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('planet', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('Sun', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('terrestrial', 'JJ'),
#  ('planet', 'NN'),
#  ('and', 'CC'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('closest', 'JJS'),
#  ('in', 'IN'),
#  ('mass', 'NN'),
#  ('and', 'CC'),
#  ('size', 'NN'),
#  ('to', 'TO'),
#  ('its', 'PRP$'),
#  ('orbital', 'JJ'),
#  ('neighbour', 'JJ'),
#  ('Earth', 'NN'),
#  ('.', '.'),
#  ('Venus', 'NNP'),
#  ('is', 'VBZ'),
#  ('notable', 'JJ'),
#  ('for', 'IN'),
#  ('having', 'VBG'),
#  ('the', 'DT'),
#  ('densest', 'JJS'),
#  ('atmosphere', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('terrestrial', 'JJ'),
#  ('planets', 'NNS'),
#  (',', ','),
#  ('composed', 'VBD'),
#  ('mostly', 'RB'),
#  ('of', 'IN'),
#  ('carbon', 'NN'),
#  ('dioxide', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('thick', 'NN'),
#  (',', ','),
#  ('global', 'JJ'),
# ...

# %%
## Print only noun
nouns = [word for word, pos in tags if 'NN' in pos]

# %%
nouns
# Out:
# ['Venus',
#  'planet',
#  'Sun',
#  'planet',
#  'mass',
#  'size',
#  'Earth',
#  'Venus',
#  'atmosphere',
#  'planets',
#  'carbon',
#  'dioxide',
#  'thick',
#  'acid',
#  'cloud',
#  'cover',
#  'surface',
#  'temperature',
#  'K',
#  '°C',
#  '°F',
#  'pressure',
#  'times',
#  'Earth',
#  'sea',
#  'level',
#  'conditions',
#  'carbon',
#  'dioxide',
#  'state',
#  'close',
#  'Venus',
#  'surface']

# %%
## adjective and noun together
nouns = [word for word, pos in tags if 'NN' in pos]

# %%
for i in range(len(tags)):
  #print(tags[i][1])
  if tags[i][1] == 'NN' and tags[i-1][1] == 'JJ':
    print(tags[i][0], tags[i-1][0])
# Out:
# planet second
# planet terrestrial
# Earth neighbour
# acid sulfuric
# temperature mean
# state supercritical
